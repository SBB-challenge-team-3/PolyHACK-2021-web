# %% [markdown]
# <a href="https://colab.research.google.com/github/SBB-challenge-team-3/PolyHACK-2021/blob/main/How%20to/Journey_Service_API.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#import requests and json libraries
import requests
import json
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# get the token
toeken_data = {
  'grant_type': 'client_credentials',
  'client_id': '10e4b078-dd1f-4faa-8f0b-a0111ddd5398',
  'client_secret': 'Zj47Q~R4iOfZc.Iuadm8UtIFGN7cEtmhqS-Fw',
  'scope' : 'api://c11fa6b1-edab-4554-a43d-8ab71b016325/.default'
}

token_request = requests.post('https://login.microsoftonline.com/2cda5d11-f0ac-46b3-967d-af1b2e1bd01a/oauth2/v2.0/token', data=toeken_data).json()

token = token_request['access_token']

headers = { 'Authorization': f"Bearer {token}" }

# %%
def outdooractive():
    PROJECT_KEY = "api-dev-oa"
    API_KEY = "yourtest-outdoora-ctiveapi"
    ROOT_URL = "http://www.outdooractive.com/api/"
    ROOT_PROJECT_URL = f"{ROOT_URL}project/{PROJECT_KEY}"
    headers = {
        "Accept" : "application/json"
    }
    params = {
        "key" : API_KEY
    }
    
    # Create name to id dictionary for categories
    url = ROOT_PROJECT_URL + "/category/tree/tours"
    r = requests.get(url, params=params, headers=headers)
    categories = {}
    for el in r.json()['category']:
        categories[el['name']] = el['id']

    url = ROOT_PROJECT_URL + "/filter/tour"
    params['category'] = categories['Hiking']
    r = requests.get(url, params=params, headers=headers)
    object_ids = []
    for el in r.json()['data']:
        object_ids.append(el['id'])
    
outdooractive()
# Out:
# 3101

# %% [markdown]
# Trips v2 function

# %% [markdown]
# Location API

# %%
# # this makes the output box smaller cuz otherwise its too big
# from google.colab.output import eval_js
# eval_js('google.colab.output.setIframeHeight("500")')

long_lat={
    "latitude" : "46.50987898354116",
    "longitude" : "6.851377800525659",
}

location_query = {
    "radius" : "1000",  # in meters
    "type" : "STATION", # one could also search for POI's, ADDRESSES or ALL of them 
}

locations_response=requests.get(f"https://journey-service-int.api.sbb.ch/b2c/v2/locations/{long_lat['latitude']}/{long_lat['longitude']}", params=location_query,  headers=headers).json()

print(json.dumps(locations_response, indent=2))
# Out:
# [
#   {
#     "type": "STATION",
#     "uicOrId": "8504960",
#     "name": "Attalens, village",
#     "coordinatesWGS84": {
#       "longitude": 6.848576,
#       "latitude": 46.510143,
#       "latitudeDecimalDegrees": 46.510143,
#       "longitudeDecimalDegrees": 6.848576
#     },
#     "cantonCH": "FR",
#     "distance": 216,
#     "categories": [],
#     "vehicleTypes": [
#       "BUS"
#     ],
#     "weight": 471,
#     "destinationTrends": null,
#     "tariffBorderPoint": false
#   },
#   {
#     "type": "STATION",
#     "uicOrId": "8579193",
#     "name": "Attalens, Corcelles",
#     "coordinatesWGS84": {
#       "longitude": 6.849043,
#       "latitude": 46.51248,
#       "latitudeDecimalDegrees": 46.51248,
#       "longitudeDecimalDegrees": 6.849043
#     },
#     "cantonCH": "FR",
#     "distance": 339,
#     "categories": [],
#     "vehicleTypes": [
#       "BUS"
#     ],
#     "weight": 471,
#     "destinationTrends": null,
#     "tariffBorderPoint": false
#   },
#   {
#     "type": "STATION",
#     "uicOrId": "8579191",
#     "name": "Attalens, La Fin",
#     "coordinatesWGS84": {
#       "longitude": 6.850481,
#       "latitude": 46.506268,
#       "latitudeDecimalDegrees": 46.506268,
#       "longitudeDecimalDegrees": 6.850481
#     },
#     "cantonCH": "FR",
#     "distance": 407,
#     "categories": [],
#     "vehicleTypes": [
#       "BUS"
#     ],
#     "weight": 471,
#     "destinationTrends": null,
#     "tariffBorderPoint": false
#   },
#   {
#     "type": "STATION",
#     "uicOrId": "8595678",
#     "name": "Attalens, Fin du Clos",
#     "coordinatesWGS84": {
#       "longitude": 6.847326,
#       "latitude": 46.515653,
#       "latitudeDecimalDegrees": 46.515653,
#       "longitudeDecimalDegrees": 6.847326
#     },
#     "cantonCH": "FR",
#     "distance": 713,
#     "categories": [],
#     "vehicleTypes": [
#       "BUS"
#     ],
#     "weight": 471,
#     "destinationTrends": null,
#     "tariffBorderPoint": false
#   }
# ]

# %%
trip_query = {
    'originValue' : '8507000',
    'destinationValue' : '8503000',
    
}

trip_request = requests.get('https://journey-service-int.api.sbb.ch/b2c/v2/trips', params=trip_query, headers=headers).json()

print(json.dumps(trip_request, indent=2))
# Out:
# [
#   {
#     "reconstructionContext": "..._EQEEARARCvBG_wEaBjAwMDAxMSICSUMqATgyBTEwODM1Gj0KAlZSEiFWRUxPUzogUmVzZXJ2aWVydW5nIG9ibGlnYXRvcmlzY2gY______8BAwQBIAEGBQE8ARo2CgJSIBIaUGxhdHpyZR09FG3DtmdsaV44AHgiDQoCWk8SAzgzNRgFIAcqDlBVQkxJQ19KT1VSTkVZ",
#     "duration": "PT1H12M",
#     "transfers": 0,
#     "ecoBalance": null,
#     "alternative": false,
#     "valid": true,
#     "individualChangeTime": false,
#     "legs": [
#       {
#         "type": "PUBLIC_JOURNEY",
#         "stops": [
#           {
#             "type": "STATION",
#             "uicOrId": "8507000",
#             "name": "Bern",
#             "coordinates": {
#               "longitude": 7.439122,
#               "latitude": 46.948825,
#               "latitudeDecimalDegrees": 46.948825,
#               "longitudeDecimalDegrees": 7.439122
#             },
#             "cantonCH": "BE",
#             "routeIndex": 5,
#             "arrivalPrognosisType": null,
#             "departurePrognosisType": "PROGNOSED",
#             "stopStatus": "PLANNED",
#             "boardingAlightingStatus": "BOARDING_ALIGHTING",
#             "boarding": true,
#             "boardingRt": null,
#             "alighting": true,
#             "alightingRt": null,
#             "virtual": false,
#             "notServiced": false,
#             "requestStop": false,
#             "arrivalTrack": null,
#             "arrivalTrackRt": null,
#             "arrivalPlatformChanged": false,
#             "departureTrack": "1",
#             "departureTrackFormatted": "1",
#             "departureTrackRt": "2",
#             "departurePlatformChanged": true,
#             "unplanned": false,
#             "cancelled": false,
#             "arrivalDateTime": null,
#             "arrivalDateTimeRt": null,
#             "arrivalDelayText": null,
#             "departureDateTime": "2021-10-30T21:02:00+02:00",
#             "departureDateTimeRt": null,
#             "departureDelayText": "",
#             "delayUndefined": false,
#             "avgOccupancyFirstClass": "LOW",
#             "avgOccupancySecondClass": "HIGH",
#             "accessibility": [],
#             "accessibilityMostRelevant": null,
#             "exitSide": null,
#             "rank": null,
#             "tariffBorderPoint": false
#           },
#           {
#             "type": "STATION",
#             "uicOrId": "8503000",
#             "name": "Z\u00fcrich HB",
#             "coordinates": {
#               "longitude": 8.540193,
#               "latitude": 47.378177,
#               "latitudeDecimalDegrees": 47.378177,
#               "longitudeDecimalDegrees": 8.540193
#             },
#             "cantonCH": "ZH",
#             "routeIndex": 7,
#             "arrivalPrognosisType": "PROGNOSED",
#             "departurePrognosisType": null,
#             "stopStatus": "PLANNED",
#             "boardingAlightingStatus": "BOARDING_ALIGHTING",
#             "boarding": true,
#             "boardingRt": null,
#             "alighting": true,
#             "alightingRt": null,
#             "virtual": false,
#             "notServiced": false,
#             "requestStop": false,
#             "arrivalTrack": "13",
#             "arrivalTrackRt": "13",
#             "arrivalPlatformChanged": false,
#             "departureTrack": null,
#             "departureTrackFormatted": null,
#             "departureTrackRt": null,
#             "departurePlatformChanged": false,
#             "unplanned": false,
#             "cancelled": false,
#             "arrivalDateTime": "2021-10-30T22:14:00+02:00",
#             "arrivalDateTimeRt": null,
#             "arrivalDelayText": "",
#             "departureDateTime": null,
#             "departureDateTimeRt": null,
#             "departureDelayText": null,
#             "delayUndefined": false,
#             "avgOccupancyFirstClass": "UNKNOWN",
#             "avgOccupancySecondClass": "UNKNOWN",
#             "accessibility": [],
#             "accessibilityMostRelevant": null,
#             "exitSide": null,
#             "rank": null,
#             "tariffBorderPoint": false
#           }
#         ],
#         "transportProducts": [
#           {
#             "name": "IC 8",
#             "numberFormatted": "10835",
#             "number": "10835",
#             "line": "8",
#             "category": "EUROCITY_INTERCITY_ICN_INTERCITYNIGHT_SUPERCITY",
#             "categoryCode": 1,
#             "categoryShortForm": "IC",
#             "categoryLongForm": "InterCity",
#             "operatorName": "Schweizerische Bundesbahnen SBB",
#             "operatorShortName": "SBB",
#             "operatorNumber": "000011",
#             "routeIndexFrom": null,
#             "routeIndexTo": null,
#             "trackTranslation": "Gleis",
#             "trackTranslationShort": "Gl.",
#             "vehicleType": "TRAIN",
#             "vehicleIconName": "SBB_oev_b_t02"
#           }
#         ],
#         "serviceDays": [],
#         "duration": "PT1H12M",
#         "distance": null,
#         "direction": "Z\u00fcrich HB",
#         "journeyStatus": "PLANNED",
#         "journeyReference": "1|14594|13|85|30102021",
#         "messages": [
#           {
#             "id": "24903",
#             "category": "END_MESSAGE",
#             "priority": 60,
#             "formattedHeader": "Endmeldung: BERN",
#             "formattedFooter": "Endmeldung: Die St\u00f6rung im Grossraum BERN konnte behoben werden. (Bern)",
#             "formattedFooterShort": "Die St\u00f6rung im Grossraum BERN konnte behoben werden.",
#             "validFromStop": {
#               "type": "STATION",
#               "uicOrId": "8507000",
#               "name": "Bern",
#               "coordinates": {
#                 "longitude": 7.439122,
#                 "latitude": 46.948825,
#                 "latitudeDecimalDegrees": 46.948825,
#                 "longitudeDecimalDegrees": 7.439122
#               },
#               "cantonCH": null,
#               "routeIndex": null,
#               "arrivalPrognosisType": null,
#               "departurePrognosisType": null,
#               "stopStatus": "PLANNED",
#               "boardingAlightingStatus": "BOARDING_ALIGHTING",
#               "boarding": null,
#               "boardingRt": null,
#               "alighting": null,
#               "alightingRt": null,
#               "virtual": false,
#               "notServiced": false,
#               "requestStop": false,
#               "arrivalTrack": null,
#               "arrivalTrackRt": null,
#               "arrivalPlatformChanged": false,
#               "departureTrack": null,
#               "departureTrackFormatted": null,
#               "departureTrackRt": null,
#               "departurePlatformChanged": false,
#               "unplanned": false,
#               "cancelled": false,
#               "arrivalDateTime": null,
#               "arrivalDateTimeRt": null,
#               "arrivalDelayText": null,
#               "departureDateTime": null,
#               "departureDateTimeRt": null,
#               "departureDelayText": null,
#               "delayUndefined": false,
#               "avgOccupancyFirstClass": "UNKNOWN",
#               "avgOccupancySecondClass": "UNKNOWN",
#               "accessibility": [],
#               "accessibilityMostRelevant": null,
#               "exitSide": null,
#               "rank": null,
#               "tariffBorderPoint": null
#             },
#             "validFromStopName": "Bern",
#             "validToStop": {
#               "type": "STATION",
#               "uicOrId": "8507000",
#               "name": "Bern",
#               "coordinates": {
#                 "longitude": 7.439122,
#                 "latitude": 46.948825,
#                 "latitudeDecimalDegrees": 46.948825,
#                 "longitudeDecimalDegrees": 7.439122
#               },
#               "cantonCH": null,
#               "routeIndex": null,
#               "arrivalPrognosisType": null,
#               "departurePrognosisType": null,
#               "stopStatus": "PLANNED",
#               "boardingAlightingStatus": "BOARDING_ALIGHTING",
#               "boarding": null,
#               "boardingRt": null,
#               "alighting": null,
#               "alightingRt": null,
#               "virtual": false,
#               "notServiced": false,
#               "requestStop": false,
#               "arrivalTrack": null,
#               "arrivalTrackRt": null,
#               "arrivalPlatformChanged": false,
#               "departureTrack": null,
#               "departureTrackFormatted": null,
#               "departureTrackRt": null,
#               "departurePlatformChanged": false,
#               "unplanned": false,
#               "cancelled": false,
#               "arrivalDateTime": null,
#               "arrivalDateTimeRt": null,
#               "arrivalDelayText": null,
#               "departureDateTime": null,
#               "departureDateTimeRt": null,
#               "departureDelayText": null,
#               "delayUndefined": false,
#               "avgOccupancyFirstClass": "UNKNOWN",
#               "avgOccupancySecondClass": "UNKNOWN",
#               "accessibility": [],
#               "accessibilityMostRelevant": null,
#               "exitSide": null,
#               "rank": null,
#               "tariffBorderPoint": null
#             },
#             "validToStopName": "Bern",
#             "routeIndexFrom": 5,
#             "routeIndexTo": 5,
#             "startTime": "00:00:00",
#             "startDate": "2021-10-15",
#             "endTime": "23:59:00",
#             "endDate": "2021-11-14",
#             "startText": null,
#             "endText": null,
#             "dailyStartingAt": "00:00:00",
#             "dailyDuration": "PT23H59M0S",
#             "channels": [
#               {
#                 "name": "TIMETABLE",
#                 "urls": [],
#                 "validFromTime": "08:36:00",
#                 "validFromDate": "2021-10-15",
#                 "validToTime": "23:59:00",
#                 "validToDate": "2021-11-14"
#               }
#             ],
#             "serviceDays": null,
#             "edges": [],
#             "regions": [
#               {
#                 "name": null,
#                 "id": "BVI2",
#                 "polylineFormatted": [],
#                 "iconCoordinates": null,
#                 "geofence": null
#               },
#               {
#                 "name": null,
#                 "id": null,
#                 "polylineFormatted": [],
#                 "iconCoordinates": null,
#                 "geofence": {
#                   "center": {
#                     "longitude": 7.439131,
#                     "latitude": 46.948834,
#                     "latitudeDecimalDegrees": 46.948834,
#                     "longitudeDecimalDegrees": 7.439131
#                   },
#                   "radiusMin": null,
#                   "radiusMax": 5000
#                 }
#               }
#             ],
#             "transportProducts": [
#               {
#                 "name": null,
#                 "numberFormatted": null,
#                 "number": null,
#                 "line": null,
#                 "category": "FASTTRAIN_REGIOEXPRESS",
#                 "categoryCode": null,
#                 "categoryShortForm": null,
#                 "categoryLongForm": null,
#                 "operatorName": null,
#                 "operatorShortName": null,
#                 "operatorNumber": null,
#                 "routeIndexFrom": null,
#                 "routeIndexTo": null,
#                 "trackTranslation": null,
#                 "trackTranslationShort": null,
#                 "vehicleType": null,
#                 "vehicleIconName": null
#               },
#               {
#                 "name": null,
#                 "numberFormatted": null,
#                 "number": null,
#                 "line": null,
#                 "category": "URBANRAILWAY_STADTEXPRESS_SEMIFASTTRAIN_OMNIBUSTRAIN",
#                 "categoryCode": null,
#                 "categoryShortForm": null,
#                 "categoryLongForm": null,
#                 "operatorName": null,
#                 "operatorShortName": null,
#                 "operatorNumber": null,
#                 "routeIndexFrom": null,
#                 "routeIndexTo": null,
#                 "trackTranslation": null,
#                 "trackTranslationShort": null,
#                 "vehicleType": null,
#                 "vehicleIconName": null
#               },
#               {
#                 "name": null,
#                 "numberFormatted": null,
#                 "number": null,
#                 "line": null,
#                 "category": "INTERREGIO",
#                 "categoryCode": null,
#                 "categoryShortForm": null,
#                 "categoryLongForm": null,
#                 "operatorName": null,
#                 "operatorShortName": null,
#                 "operatorNumber": null,
#                 "routeIndexFrom": null,
#                 "routeIndexTo": null,
#                 "trackTranslation": null,
#                 "trackTranslationShort": null,
#                 "vehicleType": null,
#                 "vehicleIconName": null
#               },
#               {
#                 "name": null,
#                 "numberFormatted": null,
#                 "number": null,
#                 "line": null,
#                 "category": "BUS_COACH_TAXI",
#                 "categoryCode": null,
#                 "categoryShortForm": null,
#                 "categoryLongForm": null,
#                 "operatorName": null,
#                 "operatorShortName": null,
#                 "operatorNumber": null,
#                 "routeIndexFrom": null,
#                 "routeIndexTo": null,
#                 "trackTranslation": null,
#                 "trackTranslationShort": null,
#                 "vehicleType": null,
#                 "vehicleIconName": null
#               },
#               {
#                 "name": null,
#                 "numberFormatted": null,
#                 "number": null,
#                 "line": null,
#                 "category": "CABLEWAY_FUNICULAR_GONDOLALIFT_CHAIRLIFT",
#                 "categoryCode": null,
#                 "categoryShortForm": null,
#                 "categoryLongForm": null,
#                 "operatorName": null,
#                 "operatorShortName": null,
#                 "operatorNumber": null,
#                 "routeIndexFrom": null,
#                 "routeIndexTo": null,
#                 "trackTranslation": null,
#                 "trackTranslationShort": null,
#                 "vehicleType": null,
#                 "vehicleIconName": null
#               },
#               {
#                 "name": null,
#                 "numberFormatted": null,
#                 "number": null,
#                 "line": null,
#                 "category": "METRO_MOTORAILTRAIN_SPECIALTRAIN_URLAUBSEXPRESS",
#                 "categoryCode": null,
#                 "categoryShortForm": null,
#                 "categoryLongForm": null,
#                 "operatorName": null,
#                 "operatorShortName": null,
#                 "operatorNumber": null,
#                 "routeIndexFrom": null,
#                 "routeIndexTo": null,
#                 "trackTranslation": null,
#                 "trackTranslationShort": null,
#                 "vehicleType": null,
#                 "vehicleIconName": null
#               },
#               {
#                 "name": null,
#                 "numberFormatted": null,
#                 "number": null,
#                 "line": null,
#                 "category": "SHIP_FERRY_STEAMER",
#                 "categoryCode": null,
#                 "categoryShortForm": null,
#                 "categoryLongForm": null,
#                 "operatorName": null,
#                 "operatorShortName": null,
#                 "operatorNumber": null,
#                 "routeIndexFrom": null,
#                 "routeIndexTo": null,
#                 "trackTranslation": null,
#                 "trackTranslationShort": null,
#                 "vehicleType": null,
#                 "vehicleIconName": null
#               },
#               {
#                 "name": null,
#                 "numberFormatted": null,
#                 "number": null,
#                 "line": null,
#                 "category": "TRAMWAY",
#                 "categoryCode": null,
#                 "categoryShortForm": null,
#                 "categoryLongForm": null,
#                 "operatorName": null,
#                 "operatorShortName": null,
#                 "operatorNumber": null,
#                 "routeIndexFrom": null,
#                 "routeIndexTo": null,
#                 "trackTranslation": null,
#                 "trackTranslationShort": null,
#                 "vehicleType": null,
#                 "vehicleIconName": null
#               },
#               {
#                 "name": null,
#                 "numberFormatted": null,
#                 "number": null,
#                 "line": null,
#                 "category": "ICE_EN_CNL_CIS_ES_MET_NZ_PEN_TGV_THA_X2",
#                 "categoryCode": null,
#                 "categoryShortForm": null,
#                 "categoryLongForm": null,
#                 "operatorName": null,
#                 "operatorShortName": null,
#                 "operatorNumber": null,
#                 "routeIndexFrom": null,
#                 "routeIndexTo": null,
#                 "trackTranslation": null,
#                 "trackTranslationShort": null,
#                 "vehicleType": null,
#                 "vehicleIconName": null
#               },
#               {
#                 "name": null,
#                 "numberFormatted": null,
#                 "number": null,
#                 "line": null,
#                 "category": "EUROCITY_INTERCITY_ICN_INTERCITYNIGHT_SUPERCITY",
#                 "categoryCode": null,
#                 "categoryShortForm": null,
#                 "categoryLongForm": null,
#                 "operatorName": null,
#                 "operatorShortName": null,
#                 "operatorNumber": null,
#                 "routeIndexFrom": null,
#                 "routeIndexTo": null,
#                 "trackTranslation": null,
#                 "trackTranslationShort": null,
#                 "vehicleType": null,
#                 "vehicleIconName": null
#               }
#             ]
#           }
#         ],
#         "cancelled": false,
#         "cancelledFormatted": null,
#         "partiallyCancelled": false,
#         "partiallyCancelledFormatted": null,
#         "reachable": true,
#         "reachableFormatted": null,
#         "redirected": false,
#         "attributes": [
#           {
#             "key": "OM",
#             "value": "Maskenpflicht f\u00fcr Reisende ab 12 Jahren",
#             "priority": 1,
#             "routeIndexFrom": 5,
#             "routeIndexTo": 7,
#             "valueFormattable": null
#           },
#           {
#             "key": "WR",
#             "value": "Restaurant",
#             "priority": 1,
#             "routeIndexFrom": 5,
#             "routeIndexTo": 7,
#             "valueFormattable": null
#           },
#           {
#             "key": "FA",
#             "value": "Familienwagen mit Spielplatz",
#             "priority": 4,
#             "routeIndexFrom": 5,
#             "routeIndexTo": 7,
#             "valueFormattable": null
#           },
#           {
#             "key": "BZ",
#             "value": "Businesszone in 1. Klasse",
#             "priority": 4,
#             "routeIndexFrom": 5,
#             "routeIndexTo": 7,
#             "valueFormattable": null
#           },
#           {
#             "key": "FS",
#             "value": "Gratis-Internet mit der App SBB FreeSurf",
#             "priority": 4,
#             "routeIndexFrom": 5,
#             "routeIndexTo": 7,
#             "valueFormattable": null
#           },
#           {
#             "key": "RZ",
#             "value": "Ruhezone in 1. Klasse",
#             "priority": 4,
#             "routeIndexFrom": 5,
#             "routeIndexTo": 7,
#             "valueFormattable": null
#           },
#           {
#             "key": "VR",
#             "value": "VELOS: Reservierung obligatorisch",
#             "priority": 6,
#             "routeIndexFrom": 5,
#             "routeIndexTo": 7,
#             "valueFormattable": null
#           },
#           {
#             "key": "R",
#             "value": "Platzreservierung m\u00f6glich",
#             "priority": 8,
#             "routeIndexFrom": 5,
#             "routeIndexTo": 7,
#             "valueFormattable": null
#           }
#         ],
#         "infos": [
#           {
#             "key": "ZO",
#             "value": "835",
#             "priority": 100,
#             "routeIndexFrom": 5,
#             "routeIndexTo": 7,
#             "valueFormattable": null
#           }
#         ],
#         "formationHint": null,
#         "formationAlert": null,
#         "index": 0,
#         "polylineFormatted": "",
#         "delayedFormatted": null,
#         "platformChangedFormatted": "Gleis\u00e4nderung",
#         "groupReservationStatus": null
#       }
#     ],
#     "serviceDays": [
#       {
#         "daysRegular": null,
#         "daysIrregular": "30., 31. Okt 2021",
#         "operatingDays": [],
#         "routeIndexFrom": null,
#         "routeIndexTo": null
#       }
#     ],
#     "scrollCheckSum": "de243ceb_3",
#     "searchHint": null,
#     "summary": null,
#     "archivedConnectionReliability": null,
#     "swissNational": false
#   },
#   {
#     "reconstructionContext": "...__w0CBAEgDQkhDTA2CgJSIBIaUGxhdHpyLj0AGG3DtmdsaWNaOAA-LwE=",
#     "duration": "PT1H23M",
#     "transfers": 1,
#     "ecoBalance": null,
#     "alternative": false,
#     "valid": true,
#     "individualChangeTime": false,
#     "legs": [
#       {
#         "type": "PUBLIC_JOURNEY",
#         "stops": [
#           {
#             "type": "STATION",
#             "uicOrId": "8507000",
#             "name": "Bern",
#             "coordinates": {
#               "longitude": 7.439122,
#               "latitude": 46.948825,
#               "latitudeDecimalDegrees": 46.948825,
#               "longitudeDecimalDegrees": 7.439122
#             },
#             "cantonCH": "BE",
#             "routeIndex": 0,
#             "arrivalPrognosisType": null,
#             "departurePrognosisType": "PROGNOSED",
#             "stopStatus": "PLANNED",
#             "boardingAlightingStatus": "BOARDING_ALIGHTING",
#             "boarding": true,
#             "boardingRt": null,
#             "alighting": true,
#             "alightingRt": null,
#             "virtual": false,
#             "notServiced": false,
#             "requestStop": false,
#             "arrivalTrack": null,
#             "arrivalTrackRt": null,
#             "arrivalPlatformChanged": false,
#             "departureTrack": "9",
#             "departureTrackFormatted": "9",
#             "departureTrackRt": "9",
#             "departurePlatformChanged": false,
#             "unplanned": false,
#             "cancelled": false,
#             "arrivalDateTime": null,
#             "arrivalDateTimeRt": null,
#             "arrivalDelayText": null,
#             "departureDateTime": "2021-10-30T21:07:00+02:00",
#             "departureDateTimeRt": null,
#             "departureDelayText": "",
#             "delayUndefined": false,
#             "avgOccupancyFirstClass": "UNKNOWN",
#             "avgOccupancySecondClass": "MEDIUM",
#             "accessibility": [],
#             "accessibilityMostRelevant": null,
#             "exitSide": null,
#             "rank": null,
#             "tariffBorderPoint": false
#           },
#           {
#             "type": "STATION",
#             "uicOrId": "8500218",
#             "name": "Olten",
#             "coordinates": {
#               "longitude": 7.907685,
#               "latitude": 47.351929,
#               "latitudeDecimalDegrees": 47.351929,
#               "longitudeDecimalDegrees": 7.907685
#             },
#             "cantonCH": "SO",
#             "routeIndex": 5,
#             "arrivalPrognosisType": "PROGNOSED",
#             "departurePrognosisType": null,
#             "stopStatus": "PLANNED",
#             "boardingAlightingStatus": "BOARDING_ALIGHTING",
#             "boarding": true,
#             "boardingRt": null,
#             "alighting": true,
#             "alightingRt": null,
#             "virtual": false,
#             "notServiced": false,
#             "requestStop": false,
#             "arrivalTrack": "10",
#             "arrivalTrackRt": "10",
#             "arrivalPlatformChanged": false,
#             "departureTrack": null,
#             "departureTrackFormatted": null,
#             "departureTrackRt": null,
#             "departurePlatformChanged": false,
#             "unplanned": false,
#             "cancelled": false,
#             "arrivalDateTime": "2021-10-30T21:54:00+02:00",
#             "arrivalDateTimeRt": null,
#             "arrivalDelayText": "",
#             "departureDateTime": null,
#             "departureDateTimeRt": null,
#             "departureDelayText": null,
#             "delayUndefined": false,
#             "avgOccupancyFirstClass": "UNKNOWN",
#             "avgOccupancySecondClass": "UNKNOWN",
#             "accessibility": [],
#             "accessibilityMostRelevant": null,
#             "exitSide": null,
#             "rank": null,
#             "tariffBorderPoint": false
#           }
#         ],
#         "transportProducts": [
#           {
#             "name": "IR 17",
#             "numberFormatted": "2839",
#             "number": "2839",
#             "line": "17",
#             "category": "INTERREGIO",
#             "categoryCode": 2,
#             "categoryShortForm": "IR",
#             "categoryLongForm": "InterRegio",
#             "operatorName": "BLS AG (bls)",
#             "operatorShortName": "BLS",
#             "operatorNumber": "000033",
#             "routeIndexFrom": null,
#             "routeIndexTo": null,
#             "trackTranslation": "Gleis",
#             "trackTranslationShort": "Gl.",
#             "vehicleType": "TRAIN",
#             "vehicleIconName": "SBB_oev_b_t02"
#           }
#         ],
#         "serviceDays": [],
#         "duration": "PT47M",
#         "distance": null,
#         "direction": "Olten",
#         "journeyStatus": "PLANNED",
#         "journeyReference": "1|187195|0|85|30102021",
#         "messages": [
#           {
#             "id": "24903",
#             "category": "END_MESSAGE",
#             "priority": 60,
#             "formattedHeader": "Endmeldung: BERN",
#             "formattedFooter": "Endmeldung: Die St\u00f6rung im Grossraum BERN konnte behoben werden. (Bern)",
#             "formattedFooterShort": "Die St\u00f6rung im Grossraum BERN konnte behoben werden.",
#             "validFromStop": {
#               "type": "STATION",
#               "uicOrId": "8507000",
#               "name": "Bern",
#               "coordinates": {
#                 "longitude": 7.439122,
#                 "latitude": 46.948825,
#                 "latitudeDecimalDegrees": 46.948825,
#                 "longitudeDecimalDegrees": 7.439122
#               },
#               "cantonCH": null,
#               "routeIndex": null,
#               "arrivalPrognosisType": null,
#               "departurePrognosisType": null,
#               "stopStatus": "PLANNED",
#               "boardingAlightingStatus": "BOARDING_ALIGHTING",
#               "boarding": null,
#               "boardingRt": null,
#               "alighting": null,
#               "alightingRt": null,
#               "virtual": false,
#               "notServiced": false,
#               "requestStop": false,
#               "arrivalTrack": null,
#               "arrivalTrackRt": null,
#               "arrivalPlatformChanged": false,
#               "departureTrack": null,
#               "departureTrackFormatted": null,
#               "departureTrackRt": null,
#               "departurePlatformChanged": false,
#               "unplanned": false,
#               "cancelled": false,
#               "arrivalDateTime": null,
#               "arrivalDateTimeRt": null,
#               "arrivalDelayText": null,
#               "departureDateTime": null,
#               "departureDateTimeRt": null,
#               "departureDelayText": null,
#               "delayUndefined": false,
#               "avgOccupancyFirstClass": "UNKNOWN",
#               "avgOccupancySecondClass": "UNKNOWN",
#               "accessibility": [],
#               "accessibilityMostRelevant": null,
#               "exitSide": null,
#               "rank": null,
#               "tariffBorderPoint": null
#             },
#             "validFromStopName": "Bern",
#             "validToStop": {
#               "type": "STATION",
#               "uicOrId": "8507000",
#               "name": "Bern",
#               "coordinates": {
#                 "longitude": 7.439122,
#                 "latitude": 46.948825,
#                 "latitudeDecimalDegrees": 46.948825,
#                 "longitudeDecimalDegrees": 7.439122
#               },
#               "cantonCH": null,
#               "routeIndex": null,
#               "arrivalPrognosisType": null,
#               "departurePrognosisType": null,
#               "stopStatus": "PLANNED",
#               "boardingAlightingStatus": "BOARDING_ALIGHTING",
#               "boarding": null,
#               "boardingRt": null,
#               "alighting": null,
#               "alightingRt": null,
#               "virtual": false,
#               "notServiced": false,
#               "requestStop": false,
#               "arrivalTrack": null,
#               "arrivalTrackRt": null,
#               "arrivalPlatformChanged": false,
#               "departureTrack": null,
#               "departureTrackFormatted": null,
#               "departureTrackRt": null,
#               "departurePlatformChanged": false,
#               "unplanned": false,
#               "cancelled": false,
#               "arrivalDateTime": null,
#               "arrivalDateTimeRt": null,
#               "arrivalDelayText": null,
#               "departureDateTime": null,
#               "departureDateTimeRt": null,
#               "departureDelayText": null,
#               "delayUndefined": false,
#               "avgOccupancyFirstClass": "UNKNOWN",
#               "avgOccupancySecondClass": "UNKNOWN",
#               "accessibility": [],
#               "accessibilityMostRelevant": null,
#               "exitSide": null,
#               "rank": null,
#               "tariffBorderPoint": null
#             },
#             "validToStopName": "Bern",
#             "routeIndexFrom": 0,
#             "routeIndexTo": 0,
#             "startTime": "00:00:00",
#             "startDate": "2021-10-15",
#             "endTime": "23:59:00",
#             "endDate": "2021-11-14",
#             "startText": null,
#             "endText": null,
#             "dailyStartingAt": "00:00:00",
#             "dailyDuration": "PT23H59M0S",
#             "channels": [
#               {
#                 "name": "TIMETABLE",
#                 "urls": [],
#                 "validFromTime": "08:36:00",
#                 "validFromDate": "2021-10-15",
#                 "validToTime": "23:59:00",
#                 "validToDate": "2021-11-14"
#               }
#             ],
#             "serviceDays": null,
#             "edges": [],
#             "regions": [
#               {
#                 "name": null,
#                 "id": "BVI2",
#                 "polylineFormatted": [],
#                 "iconCoordinates": null,
#                 "geofence": null
#               },
#               {
#                 "name": null,
#                 "id": null,
#                 "polylineFormatted": [],
#                 "iconCoordinates": null,
#                 "geofence": {
#                   "center": {
#                     "longitude": 7.439131,
#                     "latitude": 46.948834,
#                     "latitudeDecimalDegrees": 46.948834,
#                     "longitudeDecimalDegrees": 7.439131
#                   },
#                   "radiusMin": null,
#                   "radiusMax": 5000
#                 }
#               }
#             ],
#             "transportProducts": [
#               {
#                 "name": null,
#                 "numberFormatted": null,
#                 "number": null,
#                 "line": null,
#                 "category": "FASTTRAIN_REGIOEXPRESS",
#                 "categoryCode": null,
#                 "categoryShortForm": null,
#                 "categoryLongForm": null,
#                 "operatorName": null,
#                 "operatorShortName": null,
#                 "operatorNumber": null,
#                 "routeIndexFrom": null,
#                 "routeIndexTo": null,
#                 "trackTranslation": null,
#                 "trackTranslationShort": null,
#                 "vehicleType": null,
#                 "vehicleIconName": null
#               },
#               {
#                 "name": null,
#                 "numberFormatted": null,
#                 "number": null,
#                 "line": null,
#                 "category": "URBANRAILWAY_STADTEXPRESS_SEMIFASTTRAIN_OMNIBUSTRAIN",
#                 "categoryCode": null,
#                 "categoryShortForm": null,
#                 "categoryLongForm": null,
#                 "operatorName": null,
#                 "operatorShortName": null,
#                 "operatorNumber": null,
#                 "routeIndexFrom": null,
#                 "routeIndexTo": null,
#                 "trackTranslation": null,
#                 "trackTranslationShort": null,
#                 "vehicleType": null,
#                 "vehicleIconName": null
#               },
#               {
#                 "name": null,
#                 "numberFormatted": null,
#                 "number": null,
#                 "line": null,
#                 "category": "INTERREGIO",
#                 "categoryCode": null,
#                 "categoryShortForm": null,
#                 "categoryLongForm": null,
#                 "operatorName": null,
#                 "operatorShortName": null,
#                 "operatorNumber": null,
#                 "routeIndexFrom": null,
#                 "routeIndexTo": null,
#                 "trackTranslation": null,
#                 "trackTranslationShort": null,
#                 "vehicleType": null,
#                 "vehicleIconName": null
#               },
#               {
#                 "name": null,
#                 "numberFormatted": null,
#                 "number": null,
#                 "line": null,
#                 "category": "BUS_COACH_TAXI",
#                 "categoryCode": null,
#                 "categoryShortForm": null,
#                 "categoryLongForm": null,
#                 "operatorName": null,
#                 "operatorShortName": null,
#                 "operatorNumber": null,
#                 "routeIndexFrom": null,
#                 "routeIndexTo": null,
#                 "trackTranslation": null,
#                 "trackTranslationShort": null,
#                 "vehicleType": null,
#                 "vehicleIconName": null
#               },
#               {
#                 "name": null,
#                 "numberFormatted": null,
#                 "number": null,
#                 "line": null,
#                 "category": "CABLEWAY_FUNICULAR_GONDOLALIFT_CHAIRLIFT",
#                 "categoryCode": null,
#                 "categoryShortForm": null,
#                 "categoryLongForm": null,
#                 "operatorName": null,
#                 "operatorShortName": null,
#                 "operatorNumber": null,
#                 "routeIndexFrom": null,
#                 "routeIndexTo": null,
#                 "trackTranslation": null,
#                 "trackTranslationShort": null,
#                 "vehicleType": null,
#                 "vehicleIconName": null
#               },
#               {
#                 "name": null,
#                 "numberFormatted": null,
#                 "number": null,
#                 "line": null,
#                 "category": "METRO_MOTORAILTRAIN_SPECIALTRAIN_URLAUBSEXPRESS",
#                 "categoryCode": null,
#                 "categoryShortForm": null,
#                 "categoryLongForm": null,
#                 "operatorName": null,
#                 "operatorShortName": null,
#                 "operatorNumber": null,
#                 "routeIndexFrom": null,
#                 "routeIndexTo": null,
#                 "trackTranslation": null,
#                 "trackTranslationShort": null,
#                 "vehicleType": null,
#                 "vehicleIconName": null
#               },
#               {
#                 "name": null,
#                 "numberFormatted": null,
#                 "number": null,
#                 "line": null,
#                 "category": "SHIP_FERRY_STEAMER",
#                 "categoryCode": null,
#                 "categoryShortForm": null,
#                 "categoryLongForm": null,
#                 "operatorName": null,
#                 "operatorShortName": null,
#                 "operatorNumber": null,
#                 "routeIndexFrom": null,
#                 "routeIndexTo": null,
#                 "trackTranslation": null,
#                 "trackTranslationShort": null,
#                 "vehicleType": null,
#                 "vehicleIconName": null
#               },
#               {
#                 "name": null,
#                 "numberFormatted": null,
#                 "number": null,
#                 "line": null,
#                 "category": "TRAMWAY",
#                 "categoryCode": null,
#                 "categoryShortForm": null,
#                 "categoryLongForm": null,
#                 "operatorName": null,
#                 "operatorShortName": null,
#                 "operatorNumber": null,
#                 "routeIndexFrom": null,
#                 "routeIndexTo": null,
#                 "trackTranslation": null,
#                 "trackTranslationShort": null,
#                 "vehicleType": null,
#                 "vehicleIconName": null
#               },
#               {
#                 "name": null,
#                 "numberFormatted": null,
#                 "number": null,
#                 "line": null,
#                 "category": "ICE_EN_CNL_CIS_ES_MET_NZ_PEN_TGV_THA_X2",
#                 "categoryCode": null,
#                 "categoryShortForm": null,
#                 "categoryLongForm": null,
#                 "operatorName": null,
#                 "operatorShortName": null,
#                 "operatorNumber": null,
#                 "routeIndexFrom": null,
#                 "routeIndexTo": null,
#                 "trackTranslation": null,
#                 "trackTranslationShort": null,
#                 "vehicleType": null,
#                 "vehicleIconName": null
#               },
#               {
#                 "name": null,
#                 "numberFormatted": null,
#                 "number": null,
#                 "line": null,
#                 "category": "EUROCITY_INTERCITY_ICN_INTERCITYNIGHT_SUPERCITY",
#                 "categoryCode": null,
#                 "categoryShortForm": null,
#                 "categoryLongForm": null,
#                 "operatorName": null,
#                 "operatorShortName": null,
#                 "operatorNumber": null,
#                 "routeIndexFrom": null,
#                 "routeIndexTo": null,
#                 "trackTranslation": null,
#                 "trackTranslationShort": null,
#                 "vehicleType": null,
#                 "vehicleIconName": null
#               }
#             ]
#           }
#         ],
#         "cancelled": false,
#         "cancelledFormatted": null,
#         "partiallyCancelled": false,
#         "partiallyCancelledFormatted": null,
#         "reachable": true,
#         "reachableFormatted": null,
#         "redirected": false,
#         "attributes": [
#           {
#             "key": "OM",
#             "value": "Maskenpflicht f\u00fcr Reisende ab 12 Jahren",
#             "priority": 1,
#             "routeIndexFrom": 0,
#             "routeIndexTo": 5,
#             "valueFormattable": null
#           }
#         ],
#         "infos": [],
#         "formationHint": null,
#         "formationAlert": null,
#         "index": 0,
#         "polylineFormatted": "",
#         "delayedFormatted": null,
#         "platformChangedFormatted": null,
#         "groupReservationStatus": null
#       },
#       {
#         "type": "PUBLIC_JOURNEY",
#         "stops": [
#           {
#             "type": "STATION",
#             "uicOrId": "8500218",
#             "name": "Olten",
#             "coordinates": {
#               "longitude": 7.907685,
#               "latitude": 47.351929,
#               "latitudeDecimalDegrees": 47.351929,
#               "longitudeDecimalDegrees": 7.907685
#             },
#             "cantonCH": "SO",
#             "routeIndex": 7,
#             "arrivalPrognosisType": null,
#             "departurePrognosisType": "PROGNOSED",
#             "stopStatus": "PLANNED",
#             "boardingAlightingStatus": "BOARDING_ALIGHTING",
#             "boarding": true,
#             "boardingRt": null,
#             "alighting": true,
#             "alightingRt": null,
#             "virtual": false,
#             "notServiced": false,
#             "requestStop": false,
#             "arrivalTrack": null,
#             "arrivalTrackRt": null,
#             "arrivalPlatformChanged": false,
#             "departureTrack": "2",
#             "departureTrackFormatted": "2",
#             "departureTrackRt": "2",
#             "departurePlatformChanged": false,
#             "unplanned": false,
#             "cancelled": false,
#             "arrivalDateTime": null,
#             "arrivalDateTimeRt": null,
#             "arrivalDelayText": null,
#             "departureDateTime": "2021-10-30T21:59:00+02:00",
#             "departureDateTimeRt": null,
#             "departureDelayText": "",
#             "delayUndefined": false,
#             "avgOccupancyFirstClass": "LOW",
#             "avgOccupancySecondClass": "HIGH",
#             "accessibility": [],
#             "accessibilityMostRelevant": null,
#             "exitSide": null,
#             "rank": null,
#             "tariffBorderPoint": false
#           },
#           {
#             "type": "STATION",
#             "uicOrId": "8503000",
#             "name": "Z\u00fcrich HB",
#             "coordinates": {
#               "longitude": 8.540193,
#               "latitude": 47.378177,
#               "latitudeDecimalDegrees": 47.378177,
#               "longitudeDecimalDegrees": 8.540193
#             },
#             "cantonCH": "ZH",
#             "routeIndex": 8,
#             "arrivalPrognosisType": "PROGNOSED",
#             "departurePrognosisType": null,
#             "stopStatus": "PLANNED",
#             "boardingAlightingStatus": "BOARDING_ALIGHTING",
#             "boarding": true,
#             "boardingRt": null,
#             "alighting": true,
#             "alightingRt": null,
#             "virtual": false,
#             "notServiced": false,
#             "requestStop": false,
#             "arrivalTrack": "14",
#             "arrivalTrackRt": "14",
#             "arrivalPlatformChanged": false,
#             "departureTrack": null,
#             "departureTrackFormatted": null,
#             "departureTrackRt": null,
#             "departurePlatformChanged": false,
#             "unplanned": false,
#             "cancelled": false,
#             "arrivalDateTime": "2021-10-30T22:30:00+02:00",
#             "arrivalDateTimeRt": null,
#             "arrivalDelayText": "",
#             "departureDateTime": null,
#             "departureDateTimeRt": null,
#             "departureDelayText": null,
#             "delayUndefined": false,
#             "avgOccupancyFirstClass": "UNKNOWN",
#             "avgOccupancySecondClass": "UNKNOWN",
#             "accessibility": [],
#             "accessibilityMostRelevant": null,
#             "exitSide": null,
#             "rank": null,
#             "tariffBorderPoint": false
#           }
#         ],
#         "transportProducts": [
#           {
#             "name": "IC 5",
#             "numberFormatted": "1539",
#             "number": "1539",
#             "line": "5",
#             "category": "EUROCITY_INTERCITY_ICN_INTERCITYNIGHT_SUPERCITY",
#             "categoryCode": 1,
#             "categoryShortForm": "IC",
#             "categoryLongForm": "InterCity",
#             "operatorName": "Schweizerische Bundesbahnen SBB",
#             "operatorShortName": "SBB",
#             "operatorNumber": "000011",
#             "routeIndexFrom": null,
#             "routeIndexTo": null,
#             "trackTranslation": "Gleis",
#             "trackTranslationShort": "Gl.",
#             "vehicleType": "TRAIN",
#             "vehicleIconName": "SBB_oev_b_t02"
#           }
#         ],
#         "serviceDays": [],
#         "duration": "PT31M",
#         "distance": null,
#         "direction": "Z\u00fcrich HB",
#         "journeyStatus": "PLANNED",
#         "journeyReference": "1|66652|0|85|30102021",
#         "messages": [],
#         "cancelled": false,
#         "cancelledFormatted": null,
#         "partiallyCancelled": false,
#         "partiallyCancelledFormatted": null,
#         "reachable": true,
#         "reachableFormatted": null,
#         "redirected": false,
#         "attributes": [
#           {
#             "key": "OM",
#             "value": "Maskenpflicht f\u00fcr Reisende ab 12 Jahren",
#             "priority": 1,
#             "routeIndexFrom": 7,
#             "routeIndexTo": 8,
#             "valueFormattable": null
#           },
#           {
#             "key": "TT",
#             "value": "Neigezug",
#             "priority": 1,
#             "routeIndexFrom": 7,
#             "routeIndexTo": 8,
#             "valueFormattable": null
#           },
#           {
#             "key": "FZ",
#             "value": "Familienzone ohne Spielplatz",
#             "priority": 4,
#             "routeIndexFrom": 7,
#             "routeIndexTo": 8,
#             "valueFormattable": null
#           },
#           {
#             "key": "BZ",
#             "value": "Businesszone in 1. Klasse",
#             "priority": 4,
#             "routeIndexFrom": 7,
#             "routeIndexTo": 8,
#             "valueFormattable": null
#           },
#           {
#             "key": "FS",
#             "value": "Gratis-Internet mit der App SBB FreeSurf",
#             "priority": 4,
#             "routeIndexFrom": 7,
#             "routeIndexTo": 8,
#             "valueFormattable": null
#           },
#           {
#             "key": "RZ",
#             "value": "Ruhezone in 1. Klasse",
#             "priority": 4,
#             "routeIndexFrom": 7,
#             "routeIndexTo": 8,
#             "valueFormattable": null
#           },
#           {
#             "key": "VR",
#             "value": "VELOS: Reservierung obligatorisch",
#             "priority": 6,
#             "routeIndexFrom": 7,
#             "routeIndexTo": 8,
#             "valueFormattable": null
#           },
#           {
#             "key": "R",
#             "value": "Platzreservierung m\u00f6glich",
#             "priority": 8,
#             "routeIndexFrom": 7,
#             "routeIndexTo": 8,
#             "valueFormattable": null
#           }
#         ],
#         "infos": [],
#         "formationHint": null,
#         "formationAlert": null,
#         "index": 1,
#         "polylineFormatted": "",
#         "delayedFormatted": null,
#         "platformChangedFormatted": null,
#         "groupReservationStatus": null
#       }
#     ],
#     "serviceDays": [
#       {
#         "daysRegular": null,
#         "daysIrregular": "30. Okt bis 11. Dez 2021 Fr, Sa; nicht 6. Nov 2021",
#         "operatingDays": [],
#         "routeIndexFrom": null,
#         "routeIndexTo": null
#       }
#     ],
#     "scrollCheckSum": "18fe3a22_3",
#     "searchHint": null,
#     "summary": null,
#     "archivedConnectionReliability": null,
#     "swissNational": false
#   },
#   {
#     "reconstructionContext": "-CgSB1NUQVRJT04SGQHAQC0xMC0zMFQyMTozMjowMCswAQYoIgdQTEFOTkVEKAQVPAH5FTwAGjI8AAwyOjQ1SjwAEAYSLAj_EQEEARARCtj_ARoGMDAwMDExIgJJQyoBMTIFMTA3MzUiDQoCWk8SAzczNRgEIAYqDlBVQkxJQ19KT1VSTkVZ",
#     "duration": "PT1H13M",
#     "transfers": 0,
#     "ecoBalance": null,
#     "alternative": false,
#     "valid": true,
#     "individualChangeTime": false,
#     "legs": [
#       {
#         "type": "PUBLIC_JOURNEY",
#         "stops": [
#           {
#             "type": "STATION",
#             "uicOrId": "8507000",
#             "name": "Bern",
#             "coordinates": {
#               "longitude": 7.439122,
#               "latitude": 46.948825,
#               "latitudeDecimalDegrees": 46.948825,
#               "longitudeDecimalDegrees": 7.439122
#             },
#             "cantonCH": "BE",
#             "routeIndex": 4,
#             "arrivalPrognosisType": null,
#             "departurePrognosisType": "PROGNOSED",
#             "stopStatus": "PLANNED",
#             "boardingAlightingStatus": "BOARDING_ALIGHTING",
#             "boarding": true,
#             "boardingRt": null,
#             "alighting": true,
#             "alightingRt": null,
#             "virtual": false,
#             "notServiced": false,
#             "requestStop": false,
#             "arrivalTrack": null,
#             "arrivalTrackRt": null,
# ...
#               "avgOccupancyFirstClass": "UNKNOWN",
#               "avgOccupancySecondClass": "UNKNOWN",
#               "accessibility": [],
#               "accessibilityMostRelevant": null,
#               "exitSide": null,
#               "rank": null,
#               "tariffBorderPoint": null
#             },
#             "validToStopName": "Bern",
#             "routeIndexFrom": 0,
#             "routeIndexTo": 0,
#             "startTime": "00:00:00",
#             "startDate": "2021-10-15",
#             "endTime": "23:59:00",
#             "endDate": "2021-11-14",
#             "startText": null,
#             "endText": null,
#             "dailyStartingAt": "00:00:00",
#             "dailyDuration": "PT23H59M0S",
#             "channels": [
#               {
#                 "name": "TIMETABLE",
#                 "urls": [],
#                 "validFromTime": "08:36:00",
#                 "validFromDate": "2021-10-15",
#                 "validToTime": "23:59:00",
#                 "validToDate": "2021-11-14"
#               }
#             ],
#             "serviceDays": null,
#             "edges": [],
#             "regions": [
#               {
#                 "name": null,
#                 "id": "BVI2",
#                 "polylineFormatted": [],
#                 "iconCoordinates": null,
#                 "geofence": null
#               },
#               {
#                 "name": null,
#                 "id": null,
#                 "polylineFormatted": [],
#                 "iconCoordinates": null,
#                 "geofence": {
#                   "center": {
#                     "longitude": 7.439131,
#                     "latitude": 46.948834,
#                     "latitudeDecimalDegrees": 46.948834,
#                     "longitudeDecimalDegrees": 7.439131
#                   },
#                   "radiusMin": null,
#                   "radiusMax": 5000
#                 }
#               }
#             ],
#             "transportProducts": [
#               {
#                 "name": null,
#                 "numberFormatted": null,
#                 "number": null,
#                 "line": null,
#                 "category": "FASTTRAIN_REGIOEXPRESS",
#                 "categoryCode": null,
#                 "categoryShortForm": null,
#                 "categoryLongForm": null,
#                 "operatorName": null,
#                 "operatorShortName": null,
#                 "operatorNumber": null,
#                 "routeIndexFrom": null,
#                 "routeIndexTo": null,
#                 "trackTranslation": null,
#                 "trackTranslationShort": null,
#                 "vehicleType": null,
#                 "vehicleIconName": null
#               },
#               {
#                 "name": null,
#                 "numberFormatted": null,
#                 "number": null,
#                 "line": null,
#                 "category": "URBANRAILWAY_STADTEXPRESS_SEMIFASTTRAIN_OMNIBUSTRAIN",
#                 "categoryCode": null,
#                 "categoryShortForm": null,
#                 "categoryLongForm": null,
#                 "operatorName": null,
#                 "operatorShortName": null,
#                 "operatorNumber": null,
#                 "routeIndexFrom": null,
#                 "routeIndexTo": null,
#                 "trackTranslation": null,
#                 "trackTranslationShort": null,
#                 "vehicleType": null,
#                 "vehicleIconName": null
#               },
#               {
#                 "name": null,
#                 "numberFormatted": null,
#                 "number": null,
#                 "line": null,
#                 "category": "INTERREGIO",
#                 "categoryCode": null,
#                 "categoryShortForm": null,
#                 "categoryLongForm": null,
#                 "operatorName": null,
#                 "operatorShortName": null,
#                 "operatorNumber": null,
#                 "routeIndexFrom": null,
#                 "routeIndexTo": null,
#                 "trackTranslation": null,
#                 "trackTranslationShort": null,
#                 "vehicleType": null,
#                 "vehicleIconName": null
#               },
#               {
#                 "name": null,
#                 "numberFormatted": null,
#                 "number": null,
#                 "line": null,
#                 "category": "BUS_COACH_TAXI",
#                 "categoryCode": null,
#                 "categoryShortForm": null,
#                 "categoryLongForm": null,
#                 "operatorName": null,
#                 "operatorShortName": null,
#                 "operatorNumber": null,
#                 "routeIndexFrom": null,
#                 "routeIndexTo": null,
#                 "trackTranslation": null,
#                 "trackTranslationShort": null,
#                 "vehicleType": null,
#                 "vehicleIconName": null
#               },
#               {
#                 "name": null,
#                 "numberFormatted": null,
#                 "number": null,
#                 "line": null,
#                 "category": "CABLEWAY_FUNICULAR_GONDOLALIFT_CHAIRLIFT",
#                 "categoryCode": null,
#                 "categoryShortForm": null,
#                 "categoryLongForm": null,
#                 "operatorName": null,
#                 "operatorShortName": null,
#                 "operatorNumber": null,
#                 "routeIndexFrom": null,
#                 "routeIndexTo": null,
#                 "trackTranslation": null,
#                 "trackTranslationShort": null,
#                 "vehicleType": null,
#                 "vehicleIconName": null
#               },
#               {
#                 "name": null,
#                 "numberFormatted": null,
#                 "number": null,
#                 "line": null,
#                 "category": "METRO_MOTORAILTRAIN_SPECIALTRAIN_URLAUBSEXPRESS",
#                 "categoryCode": null,
#                 "categoryShortForm": null,
#                 "categoryLongForm": null,
#                 "operatorName": null,
#                 "operatorShortName": null,
#                 "operatorNumber": null,
#                 "routeIndexFrom": null,
#                 "routeIndexTo": null,
#                 "trackTranslation": null,
#                 "trackTranslationShort": null,
#                 "vehicleType": null,
#                 "vehicleIconName": null
#               },
#               {
#                 "name": null,
#                 "numberFormatted": null,
#                 "number": null,
#                 "line": null,
#                 "category": "SHIP_FERRY_STEAMER",
#                 "categoryCode": null,
#                 "categoryShortForm": null,
#                 "categoryLongForm": null,
#                 "operatorName": null,
#                 "operatorShortName": null,
#                 "operatorNumber": null,
#                 "routeIndexFrom": null,
#                 "routeIndexTo": null,
#                 "trackTranslation": null,
#                 "trackTranslationShort": null,
#                 "vehicleType": null,
#                 "vehicleIconName": null
#               },
#               {
#                 "name": null,
#                 "numberFormatted": null,
#                 "number": null,
#                 "line": null,
#                 "category": "TRAMWAY",
#                 "categoryCode": null,
#                 "categoryShortForm": null,
#                 "categoryLongForm": null,
#                 "operatorName": null,
#                 "operatorShortName": null,
#                 "operatorNumber": null,
#                 "routeIndexFrom": null,
#                 "routeIndexTo": null,
#                 "trackTranslation": null,
#                 "trackTranslationShort": null,
#                 "vehicleType": null,
#                 "vehicleIconName": null
#               },
#               {
#                 "name": null,
#                 "numberFormatted": null,
#                 "number": null,
#                 "line": null,
#                 "category": "ICE_EN_CNL_CIS_ES_MET_NZ_PEN_TGV_THA_X2",
#                 "categoryCode": null,
#                 "categoryShortForm": null,
#                 "categoryLongForm": null,
#                 "operatorName": null,
#                 "operatorShortName": null,
#                 "operatorNumber": null,
#                 "routeIndexFrom": null,
#                 "routeIndexTo": null,
#                 "trackTranslation": null,
#                 "trackTranslationShort": null,
#                 "vehicleType": null,
#                 "vehicleIconName": null
#               },
#               {
#                 "name": null,
#                 "numberFormatted": null,
#                 "number": null,
#                 "line": null,
#                 "category": "EUROCITY_INTERCITY_ICN_INTERCITYNIGHT_SUPERCITY",
#                 "categoryCode": null,
#                 "categoryShortForm": null,
#                 "categoryLongForm": null,
#                 "operatorName": null,
#                 "operatorShortName": null,
#                 "operatorNumber": null,
#                 "routeIndexFrom": null,
#                 "routeIndexTo": null,
#                 "trackTranslation": null,
#                 "trackTranslationShort": null,
#                 "vehicleType": null,
#                 "vehicleIconName": null
#               }
#             ]
#           }
#         ],
#         "cancelled": false,
#         "cancelledFormatted": null,
#         "partiallyCancelled": false,
#         "partiallyCancelledFormatted": null,
#         "reachable": true,
#         "reachableFormatted": null,
#         "redirected": false,
#         "attributes": [
#           {
#             "key": "OM",
#             "value": "Maskenpflicht f\u00fcr Reisende ab 12 Jahren",
#             "priority": 1,
#             "routeIndexFrom": 0,
#             "routeIndexTo": 5,
#             "valueFormattable": null
#           }
#         ],
#         "infos": [],
#         "formationHint": null,
#         "formationAlert": null,
#         "index": 0,
#         "polylineFormatted": "",
#         "delayedFormatted": null,
#         "platformChangedFormatted": null,
#         "groupReservationStatus": null
#       },
#       {
#         "type": "PUBLIC_JOURNEY",
#         "stops": [
#           {
#             "type": "STATION",
#             "uicOrId": "8500218",
#             "name": "Olten",
#             "coordinates": {
#               "longitude": 7.907685,
#               "latitude": 47.351929,
#               "latitudeDecimalDegrees": 47.351929,
#               "longitudeDecimalDegrees": 7.907685
#             },
#             "cantonCH": "SO",
#             "routeIndex": 7,
#             "arrivalPrognosisType": null,
#             "departurePrognosisType": "CALCULATED",
#             "stopStatus": "PLANNED",
#             "boardingAlightingStatus": "BOARDING_ALIGHTING",
#             "boarding": true,
#             "boardingRt": null,
#             "alighting": true,
#             "alightingRt": null,
#             "virtual": false,
#             "notServiced": false,
#             "requestStop": false,
#             "arrivalTrack": null,
#             "arrivalTrackRt": null,
#             "arrivalPlatformChanged": false,
#             "departureTrack": "2",
#             "departureTrackFormatted": "2",
#             "departureTrackRt": "2",
#             "departurePlatformChanged": false,
#             "unplanned": false,
#             "cancelled": false,
#             "arrivalDateTime": null,
#             "arrivalDateTimeRt": null,
#             "arrivalDelayText": null,
#             "departureDateTime": "2021-10-30T23:02:00+02:00",
#             "departureDateTimeRt": null,
#             "departureDelayText": "",
#             "delayUndefined": false,
#             "avgOccupancyFirstClass": "LOW",
#             "avgOccupancySecondClass": "HIGH",
#             "accessibility": [],
#             "accessibilityMostRelevant": null,
#             "exitSide": null,
#             "rank": null,
#             "tariffBorderPoint": false
#           },
#           {
#             "type": "STATION",
#             "uicOrId": "8503000",
#             "name": "Z\u00fcrich HB",
#             "coordinates": {
#               "longitude": 8.540193,
#               "latitude": 47.378177,
#               "latitudeDecimalDegrees": 47.378177,
#               "longitudeDecimalDegrees": 8.540193
#             },
#             "cantonCH": "ZH",
#             "routeIndex": 11,
#             "arrivalPrognosisType": "CALCULATED",
#             "departurePrognosisType": null,
#             "stopStatus": "PLANNED",
#             "boardingAlightingStatus": "BOARDING_ALIGHTING",
#             "boarding": true,
#             "boardingRt": null,
#             "alighting": true,
#             "alightingRt": null,
#             "virtual": false,
#             "notServiced": false,
#             "requestStop": false,
#             "arrivalTrack": "14",
#             "arrivalTrackRt": "10",
#             "arrivalPlatformChanged": true,
#             "departureTrack": null,
#             "departureTrackFormatted": null,
#             "departureTrackRt": null,
#             "departurePlatformChanged": false,
#             "unplanned": false,
#             "cancelled": false,
#             "arrivalDateTime": "2021-10-30T23:54:00+02:00",
#             "arrivalDateTimeRt": null,
#             "arrivalDelayText": "",
#             "departureDateTime": null,
#             "departureDateTimeRt": null,
#             "departureDelayText": null,
#             "delayUndefined": false,
#             "avgOccupancyFirstClass": "UNKNOWN",
#             "avgOccupancySecondClass": "UNKNOWN",
#             "accessibility": [],
#             "accessibilityMostRelevant": null,
#             "exitSide": null,
#             "rank": null,
#             "tariffBorderPoint": false
#           }
#         ],
#         "transportProducts": [
#           {
#             "name": "IR 16",
#             "numberFormatted": "2193",
#             "number": "2193",
#             "line": "16",
#             "category": "INTERREGIO",
#             "categoryCode": 2,
#             "categoryShortForm": "IR",
#             "categoryLongForm": "InterRegio",
#             "operatorName": "Schweizerische Bundesbahnen SBB",
#             "operatorShortName": "SBB",
#             "operatorNumber": "000011",
#             "routeIndexFrom": null,
#             "routeIndexTo": null,
#             "trackTranslation": "Gleis",
#             "trackTranslationShort": "Gl.",
#             "vehicleType": "TRAIN",
#             "vehicleIconName": "SBB_oev_b_t02"
#           }
#         ],
#         "serviceDays": [],
#         "duration": "PT52M",
#         "distance": null,
#         "direction": "Z\u00fcrich HB",
#         "journeyStatus": "PLANNED",
#         "journeyReference": "1|609999|0|85|30102021",
#         "messages": [],
#         "cancelled": false,
#         "cancelledFormatted": null,
#         "partiallyCancelled": false,
#         "partiallyCancelledFormatted": null,
#         "reachable": true,
#         "reachableFormatted": null,
#         "redirected": false,
#         "attributes": [
#           {
#             "key": "OM",
#             "value": "Maskenpflicht f\u00fcr Reisende ab 12 Jahren",
#             "priority": 1,
#             "routeIndexFrom": 7,
#             "routeIndexTo": 11,
#             "valueFormattable": null
#           },
#           {
#             "key": "TT",
#             "value": "Neigezug",
#             "priority": 1,
#             "routeIndexFrom": 7,
#             "routeIndexTo": 11,
#             "valueFormattable": null
#           },
#           {
#             "key": "FS",
#             "value": "Gratis-Internet mit der App SBB FreeSurf",
#             "priority": 4,
#             "routeIndexFrom": 7,
#             "routeIndexTo": 11,
#             "valueFormattable": null
#           }
#         ],
#         "infos": [],
#         "formationHint": null,
#         "formationAlert": null,
#         "index": 1,
#         "polylineFormatted": "",
#         "delayedFormatted": null,
#         "platformChangedFormatted": "Gleis\u00e4nderung",
#         "groupReservationStatus": null
#       }
#     ],
#     "serviceDays": [
#       {
#         "daysRegular": null,
#         "daysIrregular": "30. Okt bis 11. Dez 2021 t\u00e4glich",
#         "operatingDays": [],
#         "routeIndexFrom": null,
#         "routeIndexTo": null
#       }
#     ],
#     "scrollCheckSum": "9957329c_3",
#     "searchHint": null,
#     "summary": null,
#     "archivedConnectionReliability": null,
#     "swissNational": false
#   }
# ]
